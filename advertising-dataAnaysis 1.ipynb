# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# importb dataset:
df=pd.read_csv("D:/ML n DA\Machine learning project/Advertise/advertising.csv")

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# visualization:
sns.scatterplot(df['TV'],df['Sales'],data=df,)

# %%
sns.scatterplot(df['Newspaper'],df['Sales'],data=df)

# %%
sns.scatterplot(df['Radio'],df['Sales'],data=df)

# %%
sns.pairplot(df)

# %%
sns.lmplot('TV','Sales',data=df)

# %%
sns.lmplot('Radio','Sales',data=df)

# %%
sns.lmplot('Newspaper','Sales',data=df)

# %%
# spliting the dataset:
X=df.iloc[:,:-1].values
y=df.iloc[:,3].values.reshape(-1,1)

# %%
X
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
#        [112.9,  17.4,  38.6],
#        [ 97.2,   1.5,  30. ],
#        [265.6,  20. ,   0.3],
#        [ 95.7,   1.4,   7.4],
#        [290.7,   4.1,   8.5],
#        [266.9,  43.8,   5. ],
#        [ 74.7,  49.4,  45.7],
#        [ 43.1,  26.7,  35.1],
#        [228. ,  37.7,  32. ],
#        [202.5,  22.3,  31.6],
#        [177. ,  33.4,  38.7],
#        [293.6,  27.7,   1.8],
#        [206.9,   8.4,  26.4],
#        [ 25.1,  25.7,  43.3],
#        [175.1,  22.5,  31.5],
#        [ 89.7,   9.9,  35.7],
#        [239.9,  41.5,  18.5],
#        [227.2,  15.8,  49.9],
#        [ 66.9,  11.7,  36.8],
#        [199.8,   3.1,  34.6],
#        [100.4,   9.6,   3.6],
#        [216.4,  41.7,  39.6],
#        [182.6,  46.2,  58.7],
#        [262.7,  28.8,  15.9],
#        [198.9,  49.4,  60. ],
#        [  7.3,  28.1,  41.4],
#        [136.2,  19.2,  16.6],
#        [210.8,  49.6,  37.7],
#        [210.7,  29.5,   9.3],
#        [ 53.5,   2. ,  21.4],
#        [261.3,  42.7,  54.7],
#        [239.3,  15.5,  27.3],
#        [102.7,  29.6,   8.4],
#        [131.1,  42.8,  28.9],
#        [ 69. ,   9.3,   0.9],
#        [ 31.5,  24.6,   2.2],
#        [139.3,  14.5,  10.2],
#        [237.4,  27.5,  11. ],
#        [216.8,  43.9,  27.2],
#        [199.1,  30.6,  38.7],
#        [109.8,  14.3,  31.7],
#        [ 26.8,  33. ,  19.3],
#        [129.4,   5.7,  31.3],
#        [213.4,  24.6,  13.1],
#        [ 16.9,  43.7,  89.4],
#        [ 27.5,   1.6,  20.7],
#        [120.5,  28.5,  14.2],
#        [  5.4,  29.9,   9.4],
#        [116. ,   7.7,  23.1],
#        [ 76.4,  26.7,  22.3],
#        [239.8,   4.1,  36.9],
#        [ 75.3,  20.3,  32.5],
#        [ 68.4,  44.5,  35.6],
#        [213.5,  43. ,  33.8],
#        [193.2,  18.4,  65.7],
#        [ 76.3,  27.5,  16. ],
#        [110.7,  40.6,  63.2],
#        [ 88.3,  25.5,  73.4],
#        [109.8,  47.8,  51.4],
#        [134.3,   4.9,   9.3],
#        [ 28.6,   1.5,  33. ],
#        [217.7,  33.5,  59. ],
#        [250.9,  36.5,  72.3],
#        [107.4,  14. ,  10.9],
#        [163.3,  31.6,  52.9],
#        [197.6,   3.5,   5.9],
#        [184.9,  21. ,  22. ],
#        [289.7,  42.3,  51.2],
#        [135.2,  41.7,  45.9],
#        [222.4,   4.3,  49.8],
#        [296.4,  36.3, 100.9],
#        [280.2,  10.1,  21.4],
#        [187.9,  17.2,  17.9],
#        [238.2,  34.3,   5.3],
#        [137.9,  46.4,  59. ],
#        [ 25. ,  11. ,  29.7],
#        [ 90.4,   0.3,  23.2],
#        [ 13.1,   0.4,  25.6],
#        [255.4,  26.9,   5.5],
#        [225.8,   8.2,  56.5],
#        [241.7,  38. ,  23.2],
#        [175.7,  15.4,   2.4],
#        [209.6,  20.6,  10.7],
#        [ 78.2,  46.8,  34.5],
#        [ 75.1,  35. ,  52.7],
#        [139.2,  14.3,  25.6],
#        [ 76.4,   0.8,  14.8],
#        [125.7,  36.9,  79.2],
#        [ 19.4,  16. ,  22.3],
#        [141.3,  26.8,  46.2],
#        [ 18.8,  21.7,  50.4],
#        [224. ,   2.4,  15.6],
#        [123.1,  34.6,  12.4],
#        [229.5,  32.3,  74.2],
#        [ 87.2,  11.8,  25.9],
#        [  7.8,  38.9,  50.6],
#        [ 80.2,   0. ,   9.2],
#        [220.3,  49. ,   3.2],
#        [ 59.6,  12. ,  43.1],
#        [  0.7,  39.6,   8.7],
#        [265.2,   2.9,  43. ],
#        [  8.4,  27.2,   2.1],
#        [219.8,  33.5,  45.1],
#        [ 36.9,  38.6,  65.6],
#        [ 48.3,  47. ,   8.5],
#        [ 25.6,  39. ,   9.3],
#        [273.7,  28.9,  59.7],
#        [ 43. ,  25.9,  20.5],
#        [184.9,  43.9,   1.7],
#        [ 73.4,  17. ,  12.9],
#        [193.7,  35.4,  75.6],
#        [220.5,  33.2,  37.9],
#        [104.6,   5.7,  34.4],
#        [ 96.2,  14.8,  38.9],
#        [140.3,   1.9,   9. ],
#        [240.1,   7.3,   8.7],
#        [243.2,  49. ,  44.3],
#        [ 38. ,  40.3,  11.9],
#        [ 44.7,  25.8,  20.6],
#        [280.7,  13.9,  37. ],
#        [121. ,   8.4,  48.7],
#        [197.6,  23.3,  14.2],
#        [171.3,  39.7,  37.7],
#        [187.8,  21.1,   9.5],
#        [  4.1,  11.6,   5.7],
#        [ 93.9,  43.5,  50.5],
#        [149.8,   1.3,  24.3],
#        [ 11.7,  36.9,  45.2],
#        [131.7,  18.4,  34.6],
#        [172.5,  18.1,  30.7],
#        [ 85.7,  35.8,  49.3],
#        [188.4,  18.1,  25.6],
#        [163.5,  36.8,   7.4],
#        [117.2,  14.7,   5.4],
#        [234.5,   3.4,  84.8],
#        [ 17.9,  37.6,  21.6],
#        [206.8,   5.2,  19.4],
#        [215.4,  23.6,  57.6],
#        [284.3,  10.6,   6.4],
#        [ 50. ,  11.6,  18.4],
#        [164.5,  20.9,  47.4],
#        [ 19.6,  20.1,  17. ],
#        [168.4,   7.1,  12.8],
#        [222.4,   3.4,  13.1],
#        [276.9,  48.9,  41.8],
#        [248.4,  30.2,  20.3],
#        [170.2,   7.8,  35.2],
#        [276.7,   2.3,  23.7],
#        [165.6,  10. ,  17.6],
#        [156.6,   2.6,   8.3],
#        [218.5,   5.4,  27.4],
#        [ 56.2,   5.7,  29.7],
#        [287.6,  43. ,  71.8],
#        [253.8,  21.3,  30. ],
#        [205. ,  45.1,  19.6],
#        [139.5,   2.1,  26.6],
#        [191.1,  28.7,  18.2],
#        [286. ,  13.9,   3.7],
#        [ 18.7,  12.1,  23.4],
#        [ 39.5,  41.1,   5.8],
#        [ 75.5,  10.8,   6. ],
#        [ 17.2,   4.1,  31.6],
#        [166.8,  42. ,   3.6],
#        [149.7,  35.6,   6. ],
#        [ 38.2,   3.7,  13.8],
#        [ 94.2,   4.9,   8.1],
#        [177. ,   9.3,   6.4],
#        [283.6,  42. ,  66.2],
#        [232.1,   8.6,   8.7]])

# %%
y
# Out:
# array([[22.1],
#        [10.4],
#        [12. ],
#        [16.5],
#        [17.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [15.6],
#        [12.6],
#        [17.4],
#        [ 9.2],
#        [13.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [17.5],
#        [ 5.6],
#        [20.5],
#        [ 9.7],
#        [17. ],
#        [15. ],
#        [20.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [13.2],
#        [17.4],
#        [11.9],
#        [17.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [17.9],
#        [ 8.5],
#        [16.1],
#        [10.6],
#        [23.2],
#        [19.8],
#        [ 9.7],
#        [16.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
#        [23.8],
#        [18.4],
#        [ 8.1],
#        [24.2],
#        [20.7],
#        [14. ],
#        [16. ],
#        [11.3],
#        [11. ],
#        [13.4],
#        [18.9],
#        [22.3],
#        [18.3],
#        [12.4],
#        [ 8.8],
#        [11. ],
#        [17. ],
#        [ 8.7],
#        [ 6.9],
#        [14.2],
#        [ 5.3],
#        [11. ],
#        [11.8],
#        [17.3],
#        [11.3],
#        [13.6],
#        [21.7],
#        [20.2],
#        [12. ],
#        [16. ],
#        [12.9],
#        [16.7],
#        [14. ],
#        [ 7.3],
#        [19.4],
#        [22.2],
#        [11.5],
#        [16.9],
#        [16.7],
#        [20.5],
#        [25.4],
#        [17.2],
#        [16.7],
#        [23.8],
#        [19.8],
#        [19.7],
#        [20.7],
#        [15. ],
#        [ 7.2],
#        [12. ],
#        [ 5.3],
#        [19.8],
#        [18.4],
#        [21.8],
#        [17.1],
#        [20.9],
#        [14.6],
#        [12.6],
#        [12.2],
#        [ 9.4],
#        [15.9],
#        [ 6.6],
#        [15.5],
#        [ 7. ],
#        [16.6],
#        [15.2],
#        [19.7],
#        [10.6],
#        [ 6.6],
#        [11.9],
#        [24.7],
#        [ 9.7],
#        [ 1.6],
#        [17.7],
#        [ 5.7],
#        [19.6],
#        [10.8],
#        [11.6],
#        [ 9.5],
#        [20.8],
#        [ 9.6],
#        [20.7],
#        [10.9],
#        [19.2],
#        [20.1],
#        [10.4],
#        [12.3],
#        [10.3],
#        [18.2],
#        [25.4],
#        [10.9],
#        [10.1],
#        [16.1],
#        [11.6],
#        [16.6],
#        [16. ],
#        [20.6],
#        [ 3.2],
#        [15.3],
#        [10.1],
#        [ 7.3],
#        [12.9],
#        [16.4],
#        [13.3],
#        [19.9],
#        [18. ],
#        [11.9],
#        [16.9],
#        [ 8. ],
#        [17.2],
#        [17.1],
#        [20. ],
#        [ 8.4],
#        [17.5],
#        [ 7.6],
#        [16.7],
#        [16.5],
#        [27. ],
#        [20.2],
#        [16.7],
#        [16.8],
#        [17.6],
#        [15.5],
#        [17.2],
#        [ 8.7],
#        [26.2],
#        [17.6],
#        [22.6],
#        [10.3],
#        [17.3],
#        [20.9],
#        [ 6.7],
#        [10.8],
#        [11.9],
#        [ 5.9],
#        [19.6],
#        [17.3],
#        [ 7.6],
#        [14. ],
#        [14.8],
#        [25.5],
#        [18.4]])

# %%
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.17</span>
#         </div>

# %%
display(df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             Sales VS Newspaper
#         </div>
#
#         <div id="chartFigurebc230553" class="pd_save" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-bc230553")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"cce7f7a5-74ee-4d5b-b75d-16c80f3040fb":{"roots":{"references":[{"attributes":{"children":[[{"id":"11856","subtype":"Figure","type":"Plot"},0,0]]},"id":"11914","type":"GridBox"},{"attributes":{"callback":null,"start":0},"id":"11860","type":"DataRange1d"},{"attributes":{"tools":[{"id":"11875","type":"PanTool"},{"id":"11876","type":"WheelZoomTool"},{"id":"11877","type":"BoxZoomTool"},{"id":"11878","type":"SaveTool"},{"id":"11879","type":"ResetTool"},{"id":"11880","type":"HelpTool"},{"id":"11903","type":"HoverTool"}]},"id":"11915","type":"ProxyToolbar"},{"attributes":{},"id":"11862","type":"CategoricalScale"},{"attributes":{"bottom":{"expr":{"id":"11888","type":"Stack"}},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"11889","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"11891","type":"VBar"},{"attributes":{"bottom":{"expr":{"id":"11888","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"11889","type":"Stack"}},"width":{"value":0.9},"x":{"field":"pd_stacked_col"}},"id":"11892","type":"VBar"},{"attributes":{},"id":"11864","type":"LinearScale"},{"attributes":{"data_source":{"id":"11855","type":"ColumnDataSource"},"glyph":{"id":"11891","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"name":"Newspaper","nonselection_glyph":{"id":"11892","type":"VBar"},"selection_glyph":null,"view":{"id":"11894","type":"CDSView"}},"id":"11893","type":"GlyphRenderer"},{"attributes":{"axis_label":"Sales","formatter":{"id":"11898","type":"CategoricalTickFormatter"},"major_label_orientation":1,"minor_tick_line_color":{"value":null},"ticker":{"id":"11867","type":"CategoricalTicker"}},"id":"11866","type":"CategoricalAxis"},{"attributes":{"source":{"id":"11855","type":"ColumnDataSource"}},"id":"11894","type":"CDSView"},{"attributes":{},"id":"11867","type":"CategoricalTicker"},{"attributes":{"grid_line_color":null,"ticker":{"id":"11867","type":"CategoricalTicker"}},"id":"11869","type":"Grid"},{"attributes":{},"id":"11896","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"Newspaper"},"renderers":[{"id":"11893","type":"GlyphRenderer"}]},"id":"11902","type":"LegendItem"},{"attributes":{"axis_label":"Newspaper","formatter":{"id":"11896","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"ticker":{"id":"11871","type":"BasicTicker"}},"id":"11870","type":"LinearAxis"},{"attributes":{},"id":"11898","type":"CategoricalTickFormatter"},{"attributes":{},"id":"11871","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"11900","type":"BoxAnnotation"},{"attributes":{"dimension":1,"ticker":{"id":"11871","type":"BasicTicker"}},"id":"11874","type":"Grid"},{"attributes":{"items":[{"id":"11902","type":"LegendItem"}],"location":"top_left"},"id":"11901","type":"Legend"},{"attributes":{"fields":["Newspaper"]},"id":"11889","type":"Stack"},{"attributes":{},"id":"11911","type":"Selection"},{"attributes":{"fields":[]},"id":"11888","type":"Stack"},{"attributes":{},"id":"11875","type":"PanTool"},{"attributes":{"toolbar":{"id":"11915","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"11916","type":"ToolbarBox"},{"attributes":{},"id":"11876","type":"WheelZoomTool"},{"attributes":{"children":[{"id":"11916","type":"ToolbarBox"},{"id":"11914","type":"GridBox"}]},"id":"11917","type":"Column"},{"attributes":{"overlay":{"id":"11900","type":"BoxAnnotation"}},"id":"11877","type":"BoxZoomTool"},{"attributes":{"callback":null,"data":{"Newspaper":[8.7,5.7,17.5,41.4,49.6,2.1,31.6,36.45,23.4,20.7,50.4,15.4,21.4,18.4,43.3,59.550000000000004,19.3,65.9,20.5,32.73333333333333,26.66666666666 ...

# %%
display(df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             Sales VS TV
#         </div>
#     <div id="chartFigured30dddaa" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-d30dddaa")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"fc9de091-7de7-4055-96e5-62828fa55f69":{"roots":{"references":[{"attributes":{"tools":[{"id":"11979","type":"PanTool"},{"id":"11980","type":"WheelZoomTool"},{"id":"11981","type":"BoxZoomTool"},{"id":"11982","type":"SaveTool"},{"id":"11983","type":"ResetTool"},{"id":"11984","type":"HelpTool"},{"id":"12006","type":"HoverTool"}]},"id":"12018","type":"ProxyToolbar"},{"attributes":{},"id":"11983","type":"ResetTool"},{"attributes":{"callback":null,"start":0},"id":"11964","type":"DataRange1d"},{"attributes":{},"id":"11966","type":"CategoricalScale"},{"attributes":{},"id":"11975","type":"BasicTicker"},{"attributes":{"children":[[{"id":"11961","subtype":"Figure","type":"Plot"},0,0]]},"id":"12017","type":"GridBox"},{"attributes":{"children":[{"id":"12019","type":"ToolbarBox"},{"id":"12017","type":"GridBox"}]},"id":"12020","type":"Column"},{"attributes":{},"id":"11980","type":"WheelZoomTool"},{"attributes":{},"id":"11984","type":"HelpTool"},{"attributes":{},"id":"11971","type":"CategoricalTicker"},{"attributes":{"fill_color":{"field":"x","transform":{"id":"11992","type":"CategoricalColorMapper"}},"line_color":{"field":"x","transform":{"id":"11992","type":"CategoricalColorMapper"}},"top":{"field":"counts"},"width":{"value":0.925},"x":{"field":"x"}},"id":"11994","type":"VBar"},{"attributes":{},"id":"12001","type":"CategoricalTickFormatter"},{"attributes":{"source":{"id":"11959","type":"ColumnDataSource"}},"id":"11997","type":"CDSView"},{"attributes":{"axis_label":"TV","formatter":{"id":"11999","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"ticker":{"id":"11975","type":"BasicTicker"}},"id":"11974","type":"LinearAxis"},{"attributes":{},"id":"11999","type":"BasicTickFormatter"},{"attributes":{"label":{"field":"l"},"renderers":[{"id":"11996","type":"GlyphRenderer"}]},"id":"12005","type":"LegendItem"},{"attributes":{"data_source":{"id":"11959","type":"ColumnDataSource"},"glyph":{"id":"11994","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"11995","type":"VBar"},"selection_glyph":null,"view":{"id":"11997","type":"CDSView"}},"id":"11996","type":"GlyphRenderer"},{"attributes":{},"id":"12014","type":"Selection"},{"attributes":{"below":[{"id":"11970","type":"CategoricalAxis"}],"center":[{"id":"11973","type":"Grid"},{"id":"11978","type":"Grid"},{"id":"12004","type":"Legend"}],"left":[{"id":"11974","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":495,"plot_width":731,"renderers":[{"id":"11996","type":"GlyphRenderer"}],"title":null,"toolbar":{"id":"11985","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"11960","type":"FactorRange"},"x_scale":{"id":"11966","type":"CategoricalScale"},"y_range":{"id":"11964","type":"DataRange1d"},"y_scale":{"id":"11968","type":"LinearScale"}},"id":"11961","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"11979","type":"PanTool"},{"id":"11980","type":"WheelZoomTool"},{"id":"11981","type":"BoxZoomTool"},{"id":"11982","type":"SaveTool"},{"id":"11983","type":"ResetTool"},{"id":"11984","type":"HelpTool"},{"id":"12006","type":"HoverTool"}]},"id":"11985","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"12003","type":"BoxAnnotation"},{"attributes":{"callback":null,"factors":[["1.6","TV"],["3.2","TV"],["4.8","TV"],["5.3","TV"],["5.5","TV"],["5.6","TV"],["5.7","TV"],["5.9","TV"],["6.6","TV"],["6.9","TV"],["7.0","TV"],["7.6","TV"],["8.0","TV"],["8.1","TV"],["8.5","TV"],["8.7","TV"],["8.8","TV"],["9.2","TV"],["9.4","TV"],["9.6","TV"],["9.7","TV"],["10.1","TV"],["10.3","TV"],["10.4","TV"],["10.6","TV"],["10.7","TV"],["10.8", ...

# %%
display(df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             Sales VS Radio
#         </div>
#     <div id="chartFigurebf7fdffb" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-bf7fdffb")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"71ffe88b-c82f-4637-971b-0a8860c6fd11":{"roots":{"references":[{"attributes":{},"id":"12117","type":"Selection"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"12106","type":"BoxAnnotation"},{"attributes":{"fill_color":{"field":"x","transform":{"id":"12095","type":"CategoricalColorMapper"}},"line_color":{"field":"x","transform":{"id":"12095","type":"CategoricalColorMapper"}},"top":{"field":"counts"},"width":{"value":0.925},"x":{"field":"x"}},"id":"12097","type":"VBar"},{"attributes":{},"id":"12116","type":"UnionRenderers"},{"attributes":{"callback":null,"factors":[["1.6","Radio"],["3.2","Radio"],["4.8","Radio"],["5.5","Radio"],["5.6","Radio"],["5.7","Radio"],["5.9","Radio"],["6.6","Radio"],["6.7","Radio"],["6.9","Radio"],["7.0","Radio"],["7.2","Radio"],["7.3","Radio"],["7.6","Radio"],["8.0","Radio"],["8.1","Radio"],["8.4","Radio"],["8.5","Radio"],["8.8","Radio"],["9.2","Radio"],["9.4","Radio"],["9.5","Radio"],["9.6","Radio"],["9.7","Radio"],["10.1","Radio"],["10.3","Radio"],["10.4","Radio"],["10.5","Radio"],["10.6","Radio"],["10.7","Radio"],["10.8","Radio"],["10.9","Radio"],["11.0","Radio"],["11.3","Radio"],["11.5","Radio"],["11.6","Radio"],["11.8","Radio"],["11.9","Radio"],["12.0","Radio"],["12.2","Radio"],["12.3","Radio"],["12.5","Radio"],["13.2","Radio"],["13.3","Radio"],["13.4","Radio"],["13.6","Radio"],["13.7","Radio"],["14.0","Radio"],["14.2","Radio"],["14.6","Radio"],["14.8","Radio"],["15.0","Radio"],["15.3","Radio"],["15.9","Radio"],["16.1","Radio"],["16.4","Radio"],["16.5","Radio"],["16.6","Radio"],["16.8","Radio"],["16.9","Radio"],["17.0","Radio"],["17.1","Radio"],["17.2","Radio"],["17.3","Radio"],["17.4","Radio"],["17.6","Radio"],["17.7","Radio"],["17.8","Radio"],["17.9","Radio"],["18.0","Radio"],["18.4","Radio"],["19.0","Radio"],["19.2","Radio"],["19.4","Radio"],["19.6","Radio"],["19.8","Radio"],["19.9","Radio"],["20.0","Radio"],["20.1","Radio"],["20.2","Radio"],["20.6","Radio"],["20.7","Radio"],["20.8","Radio"],["20.9","Radio"],["21.4","Radio"],["21.5","Radio"],["21.7","Radio"],["21.8","Radio"],["22.1","Radio"],["22.2","Radio"],["22.3","Radio"],["22.4","Radio"],["23.2","Radio"],["23.7","Radio"],["23.8","Radio"],["24.2","Radio"],["24.4","Radio"],["24.7","Radio"],["25.4","Radio"],["27.0","Radio"]],"range_padding":0.1},"id":"12063","type":"FactorRange"},{"attributes":{},"id":"12069","type":"CategoricalScale"},{"attributes":{"dimension":1,"ticker":{"id":"12078","type":"BasicTicker"}},"id":"12081","type":"Grid"},{"attributes":{"callback":null,"tooltips":[["Sales","@x"],["Radio","@counts{0.00}"]]},"id":"12109","type":"HoverTool"},{"attributes":{},"id":"12102","type":"BasicTickFormatter"},{"attributes":{},"id":"12083","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"12062","type":"ColumnDataSource"},"glyph":{"id":"12097","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"12098","type":"VBar"},"selection_glyph":null,"view":{"id":"12100","type":"CDSView"}},"id":"12099","type":"GlyphRenderer"},{"attributes":{},"id":"12087","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"counts"},"width":{"value":0.925},"x":{"field":"x"}},"id":"12098","type":"VBar"},{"attributes":{"axis_label":"Sales","formatter":{"id":"12104","type":"CategoricalTickFormatter"},"major_label_orientation":1,"major_label_text_color":{"value":null},"major_label_text_font_size":{"value":"0px"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"ticker":{"id":"12074","type":"CategoricalTicker"}},"id":"12073","type":"CategoricalAxis"},{"attributes":{"overlay":{"id":"12106","type":"BoxAnnota ...
